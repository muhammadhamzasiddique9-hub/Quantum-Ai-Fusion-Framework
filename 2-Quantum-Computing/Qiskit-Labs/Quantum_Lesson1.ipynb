# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadhamzasiddique9-hub/My_First_Quantum_Circuit/blob/main/Quantum_Lesson1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create a QuantumCircuit object from the QASM string
circuit = QuantumCircuit.from_qasm_str(qasm_code)

# Print the circuit to verify (optional)
print(circuit)
# Out:
#      ┌───┐     ┌─┐
# q_0: ┤ H ├──■──┤M├───
#      └───┘┌─┴─┐└╥┘┌─┐
# q_1: ─────┤ X ├─╫─┤M├
#           └───┘ ║ └╥┘
# c: 2/═══════════╩══╩═
#                 0  1
